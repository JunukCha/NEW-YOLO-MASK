# %% [markdown]
# <a href="https://colab.research.google.com/github/JunukCha/NEW-YOLO-MASK/blob/main/new_mask_yolov3_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 사본 복사해서 사용하기

# %% [markdown]
# # 런타임 유형 GPU로 설정 후 시작바랍니다.

# %% [markdown]
# # 필요한 파일 업로드

# %%
# from google.colab import files

# %%
# files.upload()

# %%
# Code
# !wget -c https://download1507.mediafire.com/9gjfxsvfg1dgoxfViD9pl-VKFjoX1XmZKm3XKCw6cJssaNygwju1x5kdmENK1xBtE2HWA_V3ovErce56nnNlqQ73m3Ne5ssgxYSe7erNcBCR3IY2YE-kdhHdvUDmFhGQo5NY_reoX-iTV-lLkISPXfmzwFmasbcxzm_wVwvbrR2w/1iy4yevwv393xd1/code_file.zip
# Out:
# --2023-09-11 13:04:03--  https://download1507.mediafire.com/9gjfxsvfg1dgoxfViD9pl-VKFjoX1XmZKm3XKCw6cJssaNygwju1x5kdmENK1xBtE2HWA_V3ovErce56nnNlqQ73m3Ne5ssgxYSe7erNcBCR3IY2YE-kdhHdvUDmFhGQo5NY_reoX-iTV-lLkISPXfmzwFmasbcxzm_wVwvbrR2w/1iy4yevwv393xd1/code_file.zip
# Resolving download1507.mediafire.com (download1507.mediafire.com)... 205.196.123.195
# Connecting to download1507.mediafire.com (download1507.mediafire.com)|205.196.123.195|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 398978 (390K), 364994 (356K) remaining [application/zip]
# Saving to: ‘code_file.zip’
#
# code_file.zip       100%[+==================>] 389.63K   410KB/s    in 0.9s
#
# 2023-09-11 13:04:05 (410 KB/s) - ‘code_file.zip’ saved [398978/398978]

# %%
# Dataset
# !wget -c https://download1594.mediafire.com/8as433kasdxgX-LrpTv5pMY07g_xjY-HveINbG8CAGgfv93Y5WKYkajV6Bpf9mnSSKGBqp98BzVozK3ja_r2WyHlnHuDdIp_bOFpxqtLzovCyZ50lClHDkIAMfGZQpgnwvFkYVf85oiVBu6uvGP5LjhhYW387y6sqL5EEQQksnQ9/wj3z625fjozxqgh/dataset.zip
# Out:
# --2023-09-11 13:04:41--  https://download1594.mediafire.com/8as433kasdxgX-LrpTv5pMY07g_xjY-HveINbG8CAGgfv93Y5WKYkajV6Bpf9mnSSKGBqp98BzVozK3ja_r2WyHlnHuDdIp_bOFpxqtLzovCyZ50lClHDkIAMfGZQpgnwvFkYVf85oiVBu6uvGP5LjhhYW387y6sqL5EEQQksnQ9/wj3z625fjozxqgh/dataset.zip
# Resolving download1594.mediafire.com (download1594.mediafire.com)... 199.91.152.94
# Connecting to download1594.mediafire.com (download1594.mediafire.com)|199.91.152.94|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 334873796 (319M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 319.36M  13.7MB/s    in 26s
#
# 2023-09-11 13:05:07 (12.4 MB/s) - ‘dataset.zip’ saved [334873796/334873796]

# %%
# Checkpoints
# !wget -c https://download938.mediafire.com/e132pip7zxygBq8nNWJEJ-0Z06MINgVbjH6lMkfXZsQ7PdHYXf_EgiywuMbz7gIe8OGgWMK12lU0GDgEXTz4oxbzKVLzc7Y4yUTqEXEfMRruK1S1Eury6VOx-ayLRW4HX5QQ3DAt85fV6Tc-w7B5_AM8rDZS01sB2yG-ZexMlMws/oxj1xlk5stnxkdw/checkpoints.zip
# Out:
# --2023-09-11 13:05:20--  https://download938.mediafire.com/e132pip7zxygBq8nNWJEJ-0Z06MINgVbjH6lMkfXZsQ7PdHYXf_EgiywuMbz7gIe8OGgWMK12lU0GDgEXTz4oxbzKVLzc7Y4yUTqEXEfMRruK1S1Eury6VOx-ayLRW4HX5QQ3DAt85fV6Tc-w7B5_AM8rDZS01sB2yG-ZexMlMws/oxj1xlk5stnxkdw/checkpoints.zip
# Resolving download938.mediafire.com (download938.mediafire.com)... 205.196.121.133
# Connecting to download938.mediafire.com (download938.mediafire.com)|205.196.121.133|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 457045793 (436M), 457011797 (436M) remaining [application/zip]
# Saving to: ‘checkpoints.zip’
#
# checkpoints.zip     100%[===================>] 435.87M  14.1MB/s    in 33s
#
# 2023-09-11 13:05:54 (13.0 MB/s) - ‘checkpoints.zip’ saved [457045793/457045793]

# %%
# !rm -rf config data testing utils
# !rm -rf cam_detect.py image_detect.py models.py train.py validate.py video_detect.py
# !unzip code_file.zip
# !unzip dataset.zip
# !unzip checkpoints.zip

# !rm -rf small_dataset
# !unzip small_dataset.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: dataset/train/0_1093.txt
#   inflating: dataset/train/0_1081.txt
#   inflating: dataset/train/0_1073.txt
#   inflating: dataset/train/0_1067.jpg
#   inflating: dataset/train/0_1061.txt
#   inflating: dataset/train/0_1050.jpg
#   inflating: dataset/train/0_1076.txt
#   inflating: dataset/train/0_1042.jpg
#   inflating: dataset/train/0_1082.txt
#   inflating: dataset/train/0_1080.jpg
#   inflating: dataset/train/0_1072.txt
#   inflating: dataset/train/0_1077.jpg
#   inflating: dataset/train/0_1084.txt
#   inflating: dataset/train/0_1056.jpg
#   inflating: dataset/train/0_1070.jpg
#   inflating: dataset/train/0_1077.txt
#   inflating: dataset/train/0_1079.jpg
#   inflating: dataset/train/0_1063.jpg
#   inflating: dataset/train/0_1058.txt
#   inflating: dataset/train/0_1052.txt
#   inflating: dataset/train/0_1065.txt
#   inflating: dataset/train/0_1066.txt
#   inflating: dataset/train/0_1072.jpg
#   inflating: dataset/train/0_1090.txt
#   inflating: dataset/train/0_1084.jpg
#   inflating: dataset/train/0_1076.jpg
#   inflating: dataset/train/0_1075.txt
#   inflating: dataset/train/0_1086.jpg
#   inflating: dataset/train/0_1092.txt
#   inflating: dataset/train/0_1079.txt
#   inflating: dataset/train/0_1062.jpg
#   inflating: dataset/train/0_1074.jpg
#   inflating: dataset/train/0_1073.jpg
#   inflating: dataset/train/0_1093.jpg
#   inflating: dataset/train/0_1087.jpg
#   inflating: dataset/train/0_1088.jpg
#   inflating: dataset/train/0_1085.txt
#   inflating: dataset/train/0_1063.txt
#   inflating: dataset/train/0_1097.txt
#   inflating: dataset/train/0_1089.txt
#   inflating: dataset/train/0_1105.jpg
#   inflating: dataset/train/0_1085.jpg
#   inflating: dataset/train/0_1106.jpg
#   inflating: dataset/train/0_1104.txt
#   inflating: dataset/validate/0_1895.jpg
#   inflating: dataset/train/0_1075.jpg
#   inflating: dataset/train/0_1100.jpg
#   inflating: dataset/train/0_1096.jpg
#   inflating: dataset/train/0_1080.txt
#   inflating: dataset/train/0_1078.jpg
#   inflating: dataset/train/0_1083.txt
#   inflating: dataset/train/0_1096.txt
#   inflating: dataset/train/0_1092.jpg
#   inflating: dataset/train/0_1082.jpg
#   inflating: dataset/train/0_1083.jpg
#   inflating: dataset/train/0_1074.txt
#   inflating: dataset/train/0_1119.jpg
#   inflating: dataset/train/0_0603.txt
#   inflating: dataset/train/0_0616.txt
#   inflating: dataset/train/0_1089.jpg
#   inflating: dataset/train/0_1091.jpg
#   inflating: dataset/validate/1_1376.txt
#   inflating: dataset/train/0_0615.jpg
#   inflating: dataset/train/0_0600.txt
#   inflating: dataset/train/0_1094.jpg
#   inflating: dataset/train/0_1095.txt
#   inflating: dataset/train/0_1095.jpg
#   inflating: dataset/train/0_1094.txt
#   inflating: dataset/train/0_1088.txt
#   inflating: dataset/validate/1_1386.jpg
#   inflating: dataset/validate/0_1922.jpg
#   inflating: dataset/train/0_0307.jpg
#   inflating: dataset/train/0_1098.txt
#   inflating: dataset/train/0_1086.txt
#   inflating: dataset/train/0_0343.jpg
#   inflating: dataset/validate/0_1888.jpg
#   inflating: dataset/train/0_0604.jpg
#   inflating: dataset/train/0_0587.txt
#   inflating: dataset/train/0_1118.jpg
#   inflating: dataset/train/0_1090.jpg
#   inflating: dataset/train/0_1115.jpg
#   inflating: dataset/train/0_1115.txt
#   inflating: dataset/train/0_1097.jpg
#   inflating: dataset/train/0_0311.jpg
#   inflating: dataset/train/0_0315.txt
#   inflating: dataset/validate/0_1895.txt
#   inflating: dataset/train/0_1098.jpg
#   inflating: dataset/validate/0_1949.txt
#   inflating: dataset/train/0_0322.txt
#   inflating: dataset/train/0_0311.txt
#   inflating: dataset/validate/0_1920.txt
#   inflating: dataset/train/0_1137.txt
#   inflating: dataset/train/0_0318.txt
#   inflating: dataset/validate/1_1370.txt
#   inflating: dataset/train/0_0339.txt
#   inflating: dataset/train/0_0341.txt
#   inflating: dataset/train/0_1099.txt
#   inflating: dataset/train/0_0603.jpg
#   inflating: dataset/train/0_0313.jpg
#   inflating: dataset/train/0_0320.txt
#   inflating: dataset/train/0_1112.jpg
#   inflating: dataset/train/0_0593.jpg
#   inflating: dataset/train/0_0604.txt
#   inflating: dataset/train/0_1100.txt
#   inflating: dataset/train/0_0338.txt
#   inflating: dataset/train/0_0318.jpg
#   inflating: dataset/train/0_0601.txt
#   inflating: dataset/train/0_0590.jpg
#   inflating: dataset/train/0_1127.txt
#   inflating: dataset/train/0_0596.jpg
#   inflating: dataset/validate/0_1934.txt
#   inflating: dataset/train/0_0594.jpg
#   inflating: dataset/train/0_1102.txt
#   inflating: dataset/train/0_0309.txt
#   inflating: dataset/train/0_1101.txt
#   inflating: dataset/train/0_1123.jpg
#   inflating: dataset/validate/0_1950.jpg
#   inflating: dataset/train/0_1113.jpg
#   inflating: dataset/validate/0_1942.jpg
#   inflating: dataset/train/0_1087.txt
#   inflating: dataset/validate/0_1887.txt
#   inflating: dataset/train/0_1108.txt
#   inflating: dataset/train/0_0317.txt
#   inflating: dataset/train/0_0595.jpg
#   inflating: dataset/train/0_1111.jpg
#   inflating: dataset/validate/0_1912.jpg
#   inflating: dataset/train/0_0598.jpg
#   inflating: dataset/train/0_0317.jpg
#   inflating: dataset/train/0_0602.jpg
#   inflating: dataset/train/0_0598.txt
#   inflating: dataset/train/0_0319.txt
#   inflating: dataset/train/0_0309.jpg
#   inflating: dataset/train/0_1140.jpg
#   inflating: dataset/train/0_0595.txt
#   inflating: dataset/validate/0_1899.txt
#   inflating: dataset/train/0_0323.txt
#   inflating: dataset/train/0_0626.txt
#   inflating: dataset/train/0_0337.jpg
#   inflating: dataset/train/0_0611.jpg
#   inflating: dataset/train/0_0343.txt
#   inflating: dataset/train/0_1106.txt
#   inflating: dataset/train/0_1107.jpg
#   inflating: dataset/train/0_0320.jpg
#   inflating: dataset/train/0_0612.txt
#   inflating: dataset/validate/0_1947.jpg
#   inflating: dataset/train/0_0319.jpg
#   inflating: dataset/validate/1_1371.txt
#   inflating: dataset/train/0_0600.jpg
#   inflating: dataset/train/0_1102.jpg
#   inflating: dataset/validate/0_1948.txt
#   inflating: dataset/train/0_0613.jpg
#   inflating: dataset/validate/0_1938.txt
#   inflating: dataset/validate/0_1851.txt
#   inflating: dataset/validate/0_1916.jpg
#   inflating: dataset/train/0_0335.txt
#   inflating: dataset/train/0_0632.jpg
#   inflating: dataset/train/0_0596.txt
#   inflating: dataset/validate/0_1900.txt
#   inflating: dataset/train/0_1101.jpg
#   inflating: dataset/train/0_0597.jpg
#   inflating: dataset/validate/0_1690.txt
#   inflating: dataset/validate/0_1704.jpg
#   inflating: dataset/train/0_1103.jpg
#   inflating: dataset/validate/1_1379.jpg
#   inflating: dataset/train/0_0615.txt
#   inflating: dataset/validate/1_1413.jpg
#   inflating: dataset/validate/0_1902.jpg
#   inflating: dataset/validate/0_1891.txt
#   inflating: dataset/train/0_1117.txt
#   inflating: dataset/train/0_1113.txt
#   inflating: dataset/train/0_0334.jpg
#   inflating: dataset/train/0_0334.txt
#   inflating: dataset/validate/0_1889.txt
#   inflating: dataset/train/0_1104.jpg
#   inflating: dataset/validate/1_1366.txt
#   inflating: dataset/train/0_0352.txt
#   inflating: dataset/validate/0_1713.txt
#   inflating: dataset/validate/0_1901.txt
#   inflating: dataset/validate/0_1702.txt
#   inflating: dataset/validate/0_1945.txt
#   inflating: dataset/validate/0_1944.txt
#   inflating: dataset/validate/0_1707.jpg
#   inflating: dataset/train/0_1123.txt
#   inflating: dataset/train/0_0606.txt
#   inflating: dataset/validate/0_1891.jpg
#   inflating: dataset/train/0_1110.jpg
#   inflating: dataset/train/0_1105.txt
#   inflating: dataset/validate/0_1913.txt
#   inflating: dataset/train/0_0607.txt
#   inflating: dataset/train/0_0323.jpg
#   inflating: dataset/train/0_1120.jpg
#   inflating: dataset/train/0_1109.txt
#   inflating: dataset/train/0_0339.jpg
#   inflating: dataset/validate/0_1936.jpg
#   inflating: dataset/train/0_1103.txt
#   inflating: dataset/train/0_0349.jpg
#   inflating: dataset/train/0_0611.txt
#   inflating: dataset/validate/0_1690.jpg
#   inflating: dataset/train/0_0617.txt
#   inflating: dataset/train/0_0354.txt
#   inflating: dataset/validate/0_1929.jpg
#   inflating: dataset/validate/0_1932.jpg
#   inflating: dataset/train/0_0619.txt
#   inflating: dataset/train/0_1121.jpg
#   inflating: dataset/train/0_0352.jpg
#   inflating: dataset/train/0_0626.jpg
#   inflating: dataset/validate/1_1698.jpg
#   inflating: dataset/validate/1_1373.jpg
#   inflating: dataset/train/0_1099.jpg
#   inflating: dataset/train/0_0609.txt
#   inflating: dataset/train/0_0614.txt
#   inflating: dataset/train/0_0609.jpg
#   inflating: dataset/validate/0_1686.jpg
#   inflating: dataset/validate/1_1540.txt
#   inflating: dataset/validate/0_1765.txt
#   inflating: dataset/train/0_0608.txt
#   inflating: dataset/train/0_0614.jpg
#   inflating: dataset/validate/0_1701.jpg
#   inflating: dataset/train/0_0369.jpg
#   inflating: dataset/train/0_0341.jpg
#   inflating: dataset/train/0_0322.jpg
#   inflating: dataset/train/0_0344.jpg
#   inflating: dataset/train/0_1110.txt
#   inflating: dataset/train/0_0321.txt
#   inflating: dataset/validate/0_1695.jpg
#   inflating: dataset/validate/0_1919.txt
#   inflating: dataset/train/0_1124.jpg
#   inflating: dataset/validate/0_1686.txt
#   inflating: dataset/validate/0_1913.jpg
#   inflating: dataset/validate/1_1720.txt
#   inflating: dataset/validate/0_1737.jpg
#   inflating: dataset/validate/0_1718.txt
#   inflating: dataset/train/0_0342.jpg
#   inflating: dataset/validate/0_1698.jpg
#   inflating: dataset/train/0_1114.jpg
#   inflating: dataset/train/0_0628.jpg
#   inflating: dataset/train/0_1122.jpg
#   inflating: dataset/validate/0_1703.txt
#   inflating: dataset/train/0_0336.txt
#   inflating: dataset/validate/0_1929.txt
#   inflating: dataset/train/0_1111.txt
#   inflating: dataset/validate/0_1692.txt
#   inflating: dataset/validate/0_1923.jpg
#   inflating: dataset/validate/0_1928.txt
#   inflating: dataset/train/0_1116.jpg
#   inflating: dataset/validate/0_1711.txt
#   inflating: dataset/validate/1_1536.txt
#   inflating: dataset/train/0_0622.jpg
#   inflating: dataset/train/0_1120.txt
#   inflating: dataset/train/0_1124.txt
#   inflating: dataset/validate/1_1696.jpg
#   inflating: dataset/train/0_0342.txt
#   inflating: dataset/validate/0_1715.jpg
#   inflating: dataset/validate/1_1694.jpg
#   inflating: dataset/validate/0_1687.txt
#   inflating: dataset/train/0_0361.jpg
#   inflating: dataset/train/0_0610.txt
#   inflating: dataset/validate/1_1679.jpg
#   inflating: dataset/train/0_0356.txt
#   inflating: dataset/validate/1_1699.txt
#   inflating: dataset/train/0_0366.jpg
#   inflating: dataset/validate/1_1377.jpg
#   inflating: dataset/train/0_1109.jpg
#   inflating: dataset/validate/1_1363.txt
#   inflating: dataset/validate/1_1553.jpg
#   inflating: dataset/train/0_0355.jpg
#   inflating: dataset/validate/0_1900.jpg
#   inflating: dataset/validate/1_1530.txt
#   inflating: dataset/train/0_0608.jpg
#   inflating: dataset/train/0_0607.jpg
#   inflating: dataset/train/0_0612.jpg
#   inflating: dataset/train/0_1117.jpg
#   inflating: dataset/train/0_0624.jpg
#   inflating: dataset/validate/0_1712.txt
#   inflating: dataset/validate/0_1918.jpg
#   inflating: dataset/validate/0_1714.jpg
#   inflating: dataset/validate/1_1530.jpg
#   inflating: dataset/train/0_0354.jpg
#   inflating: dataset/train/0_0605.jpg
#   inflating: dataset/validate/0_1911.jpg
#   inflating: dataset/train/0_0350.jpg
#   inflating: dataset/train/0_0351.txt
#   inflating: dataset/validate/1_1543.jpg
#   inflating: dataset/validate/0_1841.jpg
#   inflating: dataset/validate/1_1362.txt
#   inflating: dataset/validate/1_1669.txt
#   inflating: dataset/train/0_0361.txt
#   inflating: dataset/train/0_1130.jpg
#   inflating: dataset/validate/1_1533.txt
#   inflating: dataset/train/0_0613.txt
#   inflating: dataset/validate/1_1531.txt
#   inflating: dataset/validate/0_1943.jpg
#   inflating: dataset/validate/0_1696.txt
#   inflating: dataset/train/0_1122.txt
#   inflating: dataset/validate/0_1718.jpg
#   inflating: dataset/train/0_0324.txt
#   inflating: dataset/train/0_0351.jpg
#   inflating: dataset/validate/0_1903.jpg
#   inflating: dataset/train/0_0620.jpg
#   inflating: dataset/validate/1_1366.jpg
#   inflating: dataset/train/0_0625.jpg
#   inflating: dataset/validate/1_1373.txt
#   inflating: dataset/train/0_0606.jpg
#   inflating: dataset/train/0_1108.jpg
#   inflating: dataset/train/0_1114.txt
#   inflating: dataset/validate/0_1785.txt
#   inflating: dataset/validate/0_1839.jpg
#   inflating: dataset/train/0_1107.txt
#   inflating: dataset/validate/1_1391.txt
#   inflating: dataset/train/0_0624.txt
#   inflating: dataset/validate/0_1955.jpg
#   inflating: dataset/validate/0_1694.txt
#   inflating: dataset/validate/0_1710.txt
#   inflating: dataset/train/0_1130.txt
#   inflating: dataset/validate/1_1725.txt
#   inflating: dataset/validate/0_1705.txt
#   inflating: dataset/train/0_0325.jpg
#   inflating: dataset/validate/1_1537.jpg
#   inflating: dataset/train/0_1140.txt
#   inflating: dataset/validate/1_1688.txt
#   inflating: dataset/validate/0_1940.jpg
#   inflating: dataset/train/0_0605.txt
#   inflating: dataset/train/0_0620.txt
#   inflating: dataset/validate/0_1717.txt
#   inflating: dataset/validate/1_1697.txt
#   inflating: dataset/validate/0_1704.txt
#   inflating: dataset/validate/0_1934.jpg
#   inflating: dataset/validate/0_1720.jpg
#   inflating: dataset/train/0_0353.txt
#   inflating: dataset/train/0_1134.jpg
#   inflating: dataset/train/0_1119.txt
#   inflating: dataset/train/0_0346.txt
#   inflating: dataset/train/0_0346.jpg
#   inflating: dataset/validate/0_1716.jpg
#   inflating: dataset/train/0_1112.txt
#   inflating: dataset/train/0_1134.txt
#   inflating: dataset/train/0_1125.jpg
#   inflating: dataset/validate/1_1538.jpg
#   inflating: dataset/validate/0_1948.jpg
#   inflating: dataset/validate/1_1537.txt
#   inflating: dataset/train/0_0639.jpg
#   inflating: dataset/train/0_0349.txt
#   inflating: dataset/train/0_0634.txt
#   inflating: dataset/validate/0_1918.txt
#   inflating: dataset/train/0_1125.txt
#   inflating: dataset/validate/1_1678.txt
#   inflating: dataset/train/0_0619.jpg
#   inflating: dataset/validate/1_1528.jpg
#   inflating: dataset/train/0_0345.jpg
#   inflating: dataset/train/0_1135.jpg
#   inflating: dataset/validate/0_1714.txt
#   inflating: dataset/validate/1_1379.txt
#   inflating: dataset/train/0_0344.txt
#   inflating: dataset/validate/1_1708.jpg
#   inflating: dataset/train/0_0353.jpg
#   inflating: dataset/train/0_1136.txt
#   inflating: dataset/train/0_0360.jpg
#   inflating: dataset/validate/0_1942.txt
#   inflating: dataset/train/0_0617.jpg
#   inflating: dataset/train/0_0347.jpg
#   inflating: dataset/validate/0_1910.jpg
#   inflating: dataset/validate/0_1710.jpg
#   inflating: dataset/validate/1_1374.jpg
#   inflating: dataset/train/0_1132.txt
#   inflating: dataset/train/0_0324.jpg
#   inflating: dataset/train/0_0643.txt
#   inflating: dataset/validate/0_1730.jpg
#   inflating: dataset/train/0_1116.txt
#   inflating: dataset/validate/1_1703.txt
#   inflating: dataset/train/0_1142.txt
#   inflating: dataset/train/0_1138.jpg
#   inflating: dataset/validate/1_1367.jpg
#   inflating: dataset/validate/1_1694.txt
#   inflating: dataset/train/0_0621.txt
#   inflating: dataset/train/0_0644.txt
#   inflating: dataset/validate/0_1935.txt
#   inflating: dataset/validate/1_1693.txt
#   inflating: dataset/validate/1_1701.txt
#   inflating: dataset/validate/1_1695.txt
#   inflating: dataset/train/0_0348.jpg
#   inflating: dataset/train/0_1131.jpg
#   inflating: dataset/validate/0_1712.jpg
#   inflating: dataset/validate/1_1387.jpg
#   inflating: dataset/train/0_1131.txt
#   inflating: dataset/train/0_1160.txt
#   inflating: dataset/validate/1_1706.txt
#   inflating: dataset/train/0_0363.jpg
#   inflating: dataset/validate/0_1846.jpg
#   inflating: dataset/train/0_0350.txt
#   inflating: dataset/train/0_1118.txt
#   inflating: dataset/train/0_0358.jpg
#   inflating: dataset/train/0_0622.txt
#   inflating: dataset/validate/1_1689.txt
#   inflating: dataset/train/0_1129.txt
#   inflating: dataset/train/0_0629.jpg
#   inflating: dataset/train/0_0621.jpg
#   inflating: dataset/train/0_1136.jpg
#   inflating: dataset/validate/0_1717.jpg
#   inflating: dataset/train/0_0356.jpg
#   inflating: dataset/validate/1_1695.jpg
#   inflating: dataset/validate/0_1783.txt
#   inflating: dataset/validate/1_1702.jpg
#   inflating: dataset/validate/0_1715.txt
#   inflating: dataset/train/0_0616.jpg
#   inflating: dataset/validate/1_1705.txt
#   inflating: dataset/train/0_0630.jpg
#   inflating: dataset/validate/0_1910.txt
#   inflating: dataset/validate/0_1713.jpg
#   inflating: dataset/validate/1_1368.jpg
#   inflating: dataset/train/0_0623.jpg
#   inflating: dataset/validate/1_1370.jpg
#   inflating: dataset/train/0_1144.jpg
#   inflating: dataset/train/0_1154.jpg
#   inflating: dataset/train/0_0633.txt
#   inflating: dataset/train/0_0639.txt
#   inflating: dataset/validate/0_1930.jpg
#   inflating: dataset/train/0_1121.txt
#   inflating: dataset/validate/0_1940.txt
#   inflating: dataset/validate/0_1933.jpg
#   inflating: dataset/validate/0_1927.jpg
#   inflating: dataset/validate/0_1767.txt
#   inflating: dataset/validate/0_1834.jpg
#   inflating: dataset/validate/1_1699.jpg
#   inflating: dataset/train/0_0638.jpg
#   inflating: dataset/validate/0_1905.jpg
#   inflating: dataset/train/0_0364.jpg
#   inflating: dataset/train/0_0386.jpg
#   inflating: dataset/train/0_0348.txt
#   inflating: dataset/train/0_1139.txt
#   inflating: dataset/validate/0_1775.jpg
#   inflating: dataset/train/0_0630.txt
#   inflating: dataset/train/0_1129.jpg
#   inflating: dataset/validate/1_1705.jpg
#   inflating: dataset/validate/0_1719.txt
#   inflating: dataset/validate/1_1701.jpg
#   inflating: dataset/train/0_1174.jpg
#   inflating: dataset/train/0_1159.jpg
#   inflating: dataset/validate/0_1851.jpg
#   inflating: dataset/train/0_0633.jpg
#   inflating: dataset/train/0_0623.txt
#   inflating: dataset/train/0_0364.txt
#   inflating: dataset/train/0_0347.txt
#   inflating: dataset/validate/1_1377.txt
#   inflating: dataset/validate/1_1403.jpg
#   inflating: dataset/validate/0_1706.txt
#   inflating: dataset/validate/1_1697.jpg
#   inflating: dataset/validate/1_1554.jpg
#   inflating: dataset/validate/0_1906.jpg
#   inflating: dataset/validate/1_1378.txt
#   inflating: dataset/train/0_0381.txt
#   inflating: dataset/train/0_1141.jpg
#   inflating: dataset/validate/1_1364.txt
#   inflating: dataset/train/0_1138.txt
#   inflating: dataset/train/0_0640.jpg
#   inflating: dataset/validate/0_1720.txt
#   inflating: dataset/validate/1_1571.jpg
#   inflating: dataset/validate/0_1768.jpg
#   inflating: dataset/validate/0_1703.jpg
#   inflating: dataset/validate/1_1704.txt
#   inflating: dataset/train/0_0359.jpg
#   inflating: dataset/validate/1_1679.txt
#   inflating: dataset/train/0_0379.txt
#   inflating: dataset/train/0_1187.jpg
#   inflating: dataset/validate/1_1685.jpg
#   inflating: dataset/train/0_0359.txt
#   inflating: dataset/validate/0_1777.txt
#   inflating: dataset/train/0_1143.jpg
#   inflating: dataset/validate/1_1703.jpg
#   inflating: dataset/validate/0_1951.txt
#   inflating: dataset/validate/1_1546.jpg
#   inflating: dataset/train/0_1133.txt
#   inflating: dataset/validate/0_1711.jpg
#   inflating: dataset/validate/0_1709.jpg
#   inflating: dataset/train/0_0363.txt
#   inflating: dataset/train/0_0365.jpg
#   inflating: dataset/validate/0_1709.txt
#   inflating: dataset/validate/0_1951.jpg
#   inflating: dataset/validate/0_1776.jpg
#   inflating: dataset/train/0_0366.txt
#   inflating: dataset/train/0_1126.jpg
#   inflating: dataset/validate/1_1365.txt
#   inflating: dataset/train/0_0365.txt
#   inflating: dataset/train/0_0379.jpg
#   inflating: dataset/validate/0_1955.txt
#   inflating: dataset/validate/0_1721.txt
#   inflating: dataset/validate/1_1570.jpg
#   inflating: dataset/train/0_0384.txt
#   inflating: dataset/validate/0_1719.jpg
#   inflating: dataset/validate/1_1700.txt
#   inflating: dataset/validate/0_1843.jpg
#   inflating: dataset/validate/0_1954.jpg
#   inflating: dataset/validate/1_1678.jpg
#   inflating: dataset/validate/1_1654.jpg
#   inflating: dataset/validate/1_1622.jpg
#   inflating: dataset/validate/1_1639.jpg
#   inflating: dataset/validate/1_1651.jpg
#   inflating: dataset/validate/1_1627.txt
#   inflating: dataset/validate/1_1666.txt
#   inflating: dataset/validate/1_1620.jpg
#   inflating: dataset/validate/1_1656.jpg
#   inflating: dataset/validate/1_1630.txt
#   inflating: dataset/validate/1_1633.jpg
#   inflating: dataset/validate/1_1638.jpg
#   inflating: dataset/validate/1_1641.txt
#   inflating: dataset/validate/1_1692.txt
#   inflating: dataset/validate/1_1644.txt
#   inflating: dataset/validate/1_1693.jpg
#   inflating: dataset/validate/1_1620.txt
#   inflating: dataset/validate/1_1652.jpg
#   inflating: dataset/validate/1_1634.txt
#   inflating: dataset/validate/1_1690.jpg
#   inflating: dataset/validate/1_1642.txt
#   inflating: dataset/validate/1_1643.jpg
#   inflating: dataset/validate/1_1734.txt
#   inflating: dataset/validate/1_1650.jpg
#   inflating: dataset/validate/1_1653.txt
#   inflating: dataset/validate/1_1641.jpg
#   inflating: dataset/validate/1_1737.jpg
#   inflating: dataset/validate/1_1649.jpg
#   inflating: dataset/validate/1_1741.jpg
#   inflating: dataset/validate/1_1647.txt
#   inflating: dataset/validate/1_1646.jpg
#   inflating: dataset/validate/1_1642.jpg
#   inflating: dataset/validate/1_1645.jpg
#   inflating: dataset/validate/1_1732.jpg
#   inflating: dataset/validate/1_1631.txt
#   inflating: dataset/validate/1_1657.jpg
#   inflating: dataset/validate/1_1731.jpg
#   inflating: dataset/validate/1_1734.jpg
#   inflating: dataset/validate/1_1674.jpg
#   inflating: dataset/validate/1_1643.txt
#   inflating: dataset/validate/1_1747.jpg
#   inflating: dataset/validate/1_1648.txt
#   inflating: dataset/validate/1_1640.txt
#   inflating: dataset/validate/1_1647.jpg
#   inflating: dataset/validate/1_1651.txt
#   inflating: dataset/validate/1_1749.jpg
#   inflating: dataset/validate/1_1645.txt
#   inflating: dataset/validate/1_1667.txt
#   inflating: dataset/validate/1_1744.jpg
#   inflating: dataset/validate/1_1753.jpg
#   inflating: dataset/validate/1_1730.txt
#   inflating: dataset/validate/1_1660.jpg
#   inflating: dataset/validate/1_1655.txt
#   inflating: dataset/validate/1_1737.txt
#   inflating: dataset/validate/1_1739.txt
#   inflating: dataset/validate/1_1657.txt
#   inflating: dataset/validate/1_1652.txt
#   inflating: dataset/validate/1_1766.txt
#   inflating: dataset/validate/1_1655.jpg
#   inflating: dataset/validate/1_1649.txt
#   inflating: dataset/validate/1_1674.txt
#   inflating: dataset/validate/1_1738.jpg
#   inflating: dataset/validate/1_1650.txt
#   inflating: dataset/validate/1_1763.txt
#   inflating: dataset/validate/1_1757.jpg
#   inflating: dataset/validate/1_1757.txt
#   inflating: dataset/validate/1_1764.txt
#   inflating: dataset/validate/1_1760.txt
#   inflating: dataset/validate/1_1764.jpg
#   inflating: dataset/validate/1_1766.jpg
#   inflating: dataset/validate/1_1677.txt
#   inflating: dataset/validate/1_1735.txt
#   inflating: dataset/validate/1_1743.jpg
#   inflating: dataset/validate/1_1850.jpg
#   inflating: dataset/train/0_1309.txt
#   inflating: dataset/train/0_1281.txt
#   inflating: dataset/train/0_1276.txt
#   inflating: dataset/train/0_1273.jpg
#   inflating: dataset/train/0_1272.jpg
#   inflating: dataset/validate/1_1793.txt
#   inflating: dataset/validate/1_1804.txt
#   inflating: dataset/train/0_1273.txt
#   inflating: dataset/train/0_1280.jpg
#   inflating: dataset/validate/1_1788.txt
#   inflating: dataset/train/0_1308.txt
#   inflating: dataset/validate/1_1819.txt
#   inflating: dataset/validate/1_1828.jpg
#   inflating: dataset/validate/1_1797.txt
#   inflating: dataset/validate/1_1756.jpg
#   inflating: dataset/train/0_1279.jpg
#   inflating: dataset/validate/1_1803.jpg
#   inflating: dataset/validate/1_1806.jpg
#   inflating: dataset/validate/1_1824.txt
#   inflating: dataset/train/0_1282.txt
#   inflating: dataset/train/0_1326.txt
#   inflating: dataset/train/0_1284.txt
#   inflating: dataset/validate/1_1845.jpg
#   inflating: dataset/train/0_1291.jpg
#   inflating: dataset/validate/1_1787.jpg
#   inflating: dataset/validate/1_1825.txt
#   inflating: dataset/train/0_1284.jpg
#   inflating: dataset/validate/1_1771.jpg
#   inflating: dataset/validate/1_1836.txt
#   inflating: dataset/train/0_1272.txt
#   inflating: dataset/train/0_1296.txt
#   inflating: dataset/validate/1_1776.jpg
#   inflating: dataset/validate/1_1831.jpg
#   inflating: dataset/train/0_1285.jpg
#   inflating: dataset/train/0_1277.jpg
#   inflating: dataset/train/0_1291.txt
#   inflating: dataset/validate/1_1837.txt
#   inflating: dataset/validate/1_1812.txt
#   inflating: dataset/validate/1_1798.jpg
#   inflating: dataset/train/0_1276.jpg
#   inflating: dataset/validate/1_1835.jpg
#   inflating: dataset/validate/1_1809.jpg
#   inflating: dataset/train/0_1283.jpg
#   inflating: dataset/train/0_1287.jpg
#   inflating: dataset/train/0_1286.jpg
#   inflating: dataset/train/0_1285.txt
#   inflating: dataset/validate/1_1818.txt
#   inflating: dataset/validate/1_1768.jpg
#   inflating: dataset/validate/1_1841.txt
#   inflating: dataset/train/0_1288.jpg
#   inflating: dataset/train/0_1280.txt
#   inflating: dataset/validate/1_1806.txt
#   inflating: dataset/train/0_1290.txt
#   inflating: dataset/validate/1_1840.txt
#   inflating: dataset/train/0_1294.jpg
#   inflating: dataset/train/0_1294.txt
#   inflating: dataset/train/0_1274.txt
#   inflating: dataset/validate/1_1849.jpg
#   inflating: dataset/validate/1_1775.txt
#   inflating: dataset/train/0_1300.jpg
#   inflating: dataset/train/0_1310.jpg
#   inflating: dataset/train/0_1305.txt
#   inflating: dataset/train/0_1287.txt
#   inflating: dataset/train/0_1313.jpg
#   inflating: dataset/validate/1_1833.txt
#   inflating: dataset/train/0_1303.jpg
#   inflating: dataset/train/0_1299.jpg
#   inflating: dataset/train/0_1286.txt
#   inflating: dataset/train/0_1316.txt
#   inflating: dataset/validate/1_1845.txt
#   inflating: dataset/train/0_1297.jpg
#   inflating: dataset/validate/1_1791.txt
#   inflating: dataset/validate/1_1837.jpg
#   inflating: dataset/train/0_1304.jpg
#   inflating: dataset/train/0_1348.txt
#   inflating: dataset/train/0_1317.jpg
# ...
#   inflating: dataset/validate/0_1867.jpg
#   inflating: dataset/validate/1_1672.jpg
#   inflating: dataset/validate/1_1823.txt
#   inflating: dataset/validate/1_1590.txt
#   inflating: dataset/validate/1_1633.txt
#   inflating: dataset/validate/0_1863.txt
#   inflating: dataset/train/0_0982.jpg
#   inflating: dataset/validate/1_1817.jpg
#   inflating: dataset/validate/1_1576.jpg
#   inflating: dataset/validate/1_1805.txt
#   inflating: dataset/validate/1_1809.txt
#   inflating: dataset/train/0_0930.jpg
#   inflating: dataset/validate/1_1794.txt
#   inflating: dataset/validate/0_1856.jpg
#   inflating: dataset/train/0_0930.txt
#   inflating: dataset/train/0_0921.txt
#   inflating: dataset/train/0_0937.txt
#   inflating: dataset/validate/1_1593.jpg
#   inflating: dataset/train/0_0929.jpg
#   inflating: dataset/validate/0_1857.jpg
#   inflating: dataset/train/0_0941.jpg
#   inflating: dataset/validate/1_1577.jpg
#   inflating: dataset/validate/1_1796.txt
#   inflating: dataset/validate/1_1822.jpg
#   inflating: dataset/validate/1_1585.jpg
#   inflating: dataset/train/0_0928.txt
#   inflating: dataset/validate/1_1816.txt
#   inflating: dataset/validate/1_1584.jpg
#   inflating: dataset/validate/0_1860.txt
#   inflating: dataset/validate/0_1858.jpg
#   inflating: dataset/validate/0_1867.txt
#   inflating: dataset/validate/1_1578.txt
#   inflating: dataset/validate/0_1860.jpg
#   inflating: dataset/validate/1_1792.jpg
#   inflating: dataset/validate/1_1870.txt
#   inflating: dataset/validate/1_1879.jpg
#   inflating: dataset/validate/0_1871.jpg
#   inflating: dataset/validate/0_1864.jpg
#   inflating: dataset/validate/1_1815.jpg
#   inflating: dataset/validate/1_1592.jpg
#   inflating: dataset/validate/1_1799.jpg
#   inflating: dataset/validate/1_1852.jpg
#   inflating: dataset/validate/1_1575.jpg
#   inflating: dataset/train/0_0933.jpg
#   inflating: dataset/validate/1_1878.txt
#   inflating: dataset/validate/1_1380.jpg
#   inflating: dataset/validate/1_1600.jpg
#   inflating: dataset/train/0_0940.jpg
#   inflating: dataset/train/0_0936.jpg
#   inflating: dataset/train/0_0931.jpg
#   inflating: dataset/train/0_0944.txt
#   inflating: dataset/validate/0_1869.txt
#   inflating: dataset/validate/0_1869.jpg
#   inflating: dataset/train/0_0944.jpg
#   inflating: dataset/validate/1_1723.txt
#   inflating: dataset/validate/0_1882.txt
#   inflating: dataset/validate/1_1805.jpg
#   inflating: dataset/validate/1_1594.txt
#   inflating: dataset/train/0_0942.txt
#   inflating: dataset/validate/1_1580.txt
#   inflating: dataset/validate/0_1855.jpg
#   inflating: dataset/validate/1_1603.txt
#   inflating: dataset/validate/1_1857.jpg
#   inflating: dataset/validate/0_1862.jpg
#   inflating: dataset/train/0_0936.txt
#   inflating: dataset/validate/1_1595.jpg
#   inflating: dataset/train/0_0939.txt
#   inflating: dataset/validate/0_1884.txt
#   inflating: dataset/validate/1_1583.jpg
#   inflating: dataset/train/0_0945.jpg
#   inflating: dataset/validate/1_1796.jpg
#   inflating: dataset/train/0_0948.txt
#   inflating: dataset/train/0_0947.jpg
#   inflating: dataset/validate/1_1824.jpg
#   inflating: dataset/validate/0_1859.txt
#   inflating: dataset/validate/0_1861.txt
#   inflating: dataset/validate/0_1865.jpg
#   inflating: dataset/train/0_0942.jpg
#   inflating: dataset/validate/0_1874.txt
#   inflating: dataset/validate/1_1588.jpg
#   inflating: dataset/train/0_0945.txt
#   inflating: dataset/validate/1_1859.txt
#   inflating: dataset/validate/1_1606.jpg
#   inflating: dataset/validate/1_1595.txt
#   inflating: dataset/validate/0_1879.jpg
#   inflating: dataset/validate/1_1869.txt
#   inflating: dataset/validate/1_1613.txt
#   inflating: dataset/validate/1_1863.txt
#   inflating: dataset/train/0_0946.jpg
#   inflating: dataset/validate/1_1591.jpg
#   inflating: dataset/validate/1_1868.jpg
#   inflating: dataset/validate/1_1866.txt
#   inflating: dataset/validate/0_1870.txt
#   inflating: dataset/validate/1_1592.txt
#   inflating: dataset/validate/1_1610.jpg
#   inflating: dataset/train/0_1000.txt
#   inflating: dataset/validate/1_1884.txt
#   inflating: dataset/validate/1_1801.txt
#   inflating: dataset/train/0_0952.txt
#   inflating: dataset/validate/0_1853.jpg
#   inflating: dataset/train/0_0983.jpg
#   inflating: dataset/train/0_0965.txt
#   inflating: dataset/train/0_0938.txt
#   inflating: dataset/validate/0_1853.txt
#   inflating: dataset/validate/0_1856.txt
#   inflating: dataset/validate/1_1583.txt
#   inflating: dataset/validate/1_1607.txt
#   inflating: dataset/validate/1_1601.txt
#   inflating: dataset/validate/1_1588.txt
#   inflating: dataset/validate/1_1375.txt
#   inflating: dataset/validate/1_1601.jpg
#   inflating: dataset/validate/0_1893.jpg
#   inflating: dataset/validate/1_1875.jpg
#   inflating: dataset/validate/0_1880.jpg
#   inflating: dataset/validate/0_1876.txt
#   inflating: dataset/validate/1_1856.txt
#   inflating: dataset/validate/1_1874.txt
#   inflating: dataset/validate/1_1608.jpg
#   inflating: dataset/validate/1_1610.txt
#   inflating: dataset/validate/1_1867.jpg
#   inflating: dataset/validate/1_1857.txt
#   inflating: dataset/validate/1_1589.jpg
#   inflating: dataset/validate/1_1872.txt
#   inflating: dataset/validate/1_1599.txt
#   inflating: dataset/validate/1_1591.txt
#   inflating: dataset/validate/1_1861.txt
#   inflating: dataset/train/0_0961.txt
#   inflating: dataset/validate/0_1881.txt
#   inflating: dataset/validate/0_1883.jpg
#   inflating: dataset/validate/1_1608.txt
#   inflating: dataset/validate/1_1876.txt
#   inflating: dataset/validate/1_1600.txt
#   inflating: dataset/validate/1_1865.txt
#   inflating: dataset/train/0_0962.jpg
#   inflating: dataset/train/0_0946.txt
#   inflating: dataset/validate/1_1612.txt
#   inflating: dataset/validate/1_1851.jpg
#   inflating: dataset/train/0_0958.jpg
#   inflating: dataset/train/0_0943.jpg
#   inflating: dataset/validate/1_1884.jpg
#   inflating: dataset/validate/1_1587.jpg
#   inflating: dataset/train/0_0970.jpg
#   inflating: dataset/validate/1_1864.jpg
#   inflating: dataset/validate/1_1869.jpg
#   inflating: dataset/validate/1_1866.jpg
#   inflating: dataset/validate/1_1854.txt
#   inflating: dataset/train/0_0959.jpg
#   inflating: dataset/validate/1_1594.jpg
#   inflating: dataset/validate/1_1870.jpg
#   inflating: dataset/train/0_1018.jpg
#   inflating: dataset/validate/1_1851.txt
#   inflating: dataset/train/0_0999.txt
#   inflating: dataset/train/0_0937.jpg
#   inflating: dataset/train/0_0963.txt
#   inflating: dataset/train/0_0953.txt
#   inflating: dataset/validate/1_1880.txt
#   inflating: dataset/validate/1_1609.txt
#   inflating: dataset/validate/1_1853.jpg
#   inflating: dataset/train/0_0955.jpg
#   inflating: dataset/validate/1_1859.jpg
#   inflating: dataset/validate/1_1881.jpg
#   inflating: dataset/train/0_0957.jpg
#   inflating: dataset/validate/1_1606.txt
#   inflating: dataset/train/0_1011.txt
#   inflating: dataset/validate/1_1882.txt
#   inflating: dataset/train/0_0955.txt
#   inflating: dataset/validate/1_1613.jpg
#   inflating: dataset/train/0_0961.jpg
#   inflating: dataset/validate/1_1863.jpg
#   inflating: dataset/train/0_0965.jpg
#   inflating: dataset/train/0_0956.txt
#   inflating: dataset/train/0_0962.txt
#   inflating: dataset/validate/1_1860.txt
#   inflating: dataset/validate/1_1858.txt
#   inflating: dataset/validate/1_1907.jpg
#   inflating: dataset/train/0_0960.txt
#   inflating: dataset/train/0_0964.jpg
#   inflating: dataset/validate/1_1873.txt
#   inflating: dataset/validate/1_1881.txt
#   inflating: dataset/validate/1_1611.jpg
#   inflating: dataset/validate/1_1605.jpg
#   inflating: dataset/validate/1_1607.jpg
#   inflating: dataset/train/0_0949.jpg
#   inflating: dataset/validate/1_1876.jpg
#   inflating: dataset/validate/1_1858.jpg
#   inflating: dataset/validate/1_1862.jpg
#   inflating: dataset/train/0_0975.txt
#   inflating: dataset/train/0_0957.txt
#   inflating: dataset/validate/1_1871.txt
#   inflating: dataset/train/0_0951.jpg
#   inflating: dataset/train/0_0966.jpg
#   inflating: dataset/validate/1_1873.jpg
#   inflating: dataset/validate/1_1880.jpg
#   inflating: dataset/train/0_0963.jpg
#   inflating: dataset/train/0_0972.jpg
#   inflating: dataset/train/0_0964.txt
#   inflating: dataset/validate/1_1879.txt
#   inflating: dataset/validate/1_1878.jpg
#   inflating: dataset/validate/1_1867.txt
#   inflating: dataset/train/0_1004.jpg
#   inflating: dataset/validate/1_1871.jpg
#   inflating: dataset/validate/1_1854.jpg
#   inflating: dataset/train/0_0954.txt
#   inflating: dataset/train/0_0959.txt
#   inflating: dataset/train/0_0951.txt
#   inflating: dataset/train/0_0952.jpg
#   inflating: dataset/train/0_0953.jpg
#   inflating: dataset/train/0_0979.txt
#   inflating: dataset/train/0_0966.txt
#   inflating: dataset/validate/1_1897.jpg
#   inflating: dataset/validate/1_1883.jpg
#   inflating: dataset/validate/1_1877.txt
#   inflating: dataset/validate/1_1939.txt
#   inflating: dataset/validate/1_1864.txt
#   inflating: dataset/train/0_0956.jpg
#   inflating: dataset/validate/1_1904.txt
#   inflating: dataset/validate/1_1855.jpg
#   inflating: dataset/train/0_0971.txt
#   inflating: dataset/validate/1_1903.jpg
#   inflating: dataset/validate/1_1889.jpg
#   inflating: dataset/train/0_0967.txt
#   inflating: dataset/train/0_0990.txt
#   inflating: dataset/train/0_0976.txt
#   inflating: dataset/validate/1_1877.jpg
#   inflating: dataset/train/0_0958.txt
#   inflating: dataset/train/0_0979.jpg
#   inflating: dataset/validate/1_1910.jpg
#   inflating: dataset/train/0_0960.jpg
#   inflating: dataset/validate/1_1908.txt
#   inflating: dataset/train/0_0976.jpg
#   inflating: dataset/validate/1_1903.txt
#   inflating: dataset/train/0_0954.jpg
#   inflating: dataset/validate/1_1908.jpg
#   inflating: dataset/train/0_0997.txt
#   inflating: dataset/validate/1_1902.txt
#   inflating: dataset/validate/1_1887.txt
#   inflating: dataset/train/0_0973.jpg
#   inflating: dataset/validate/1_1892.jpg
#   inflating: dataset/train/0_0950.txt
#   inflating: dataset/validate/1_1868.txt
#   inflating: dataset/validate/1_1856.jpg
#   inflating: dataset/validate/1_1913.txt
#   inflating: dataset/validate/1_1925.txt
#   inflating: dataset/validate/1_1904.jpg
#   inflating: dataset/train/0_0982.txt
#   inflating: dataset/validate/1_1894.txt
#   inflating: dataset/validate/1_1901.jpg
#   inflating: dataset/validate/1_1889.txt
#   inflating: dataset/train/0_0991.txt
#   inflating: dataset/train/0_0969.txt
#   inflating: dataset/train/0_0950.jpg
#   inflating: dataset/train/0_0974.jpg
#   inflating: dataset/validate/1_1909.jpg
#   inflating: dataset/train/0_0967.jpg
#   inflating: dataset/validate/1_1901.txt
#   inflating: dataset/validate/1_1891.jpg
#   inflating: dataset/train/0_0949.txt
#   inflating: dataset/validate/1_1886.txt
#   inflating: dataset/train/0_1005.jpg
#   inflating: dataset/validate/1_1906.jpg
#   inflating: dataset/train/0_0972.txt
#   inflating: dataset/train/0_0980.txt
#   inflating: dataset/train/0_0973.txt
#   inflating: dataset/train/0_0968.jpg
#   inflating: dataset/train/0_0977.jpg
#   inflating: dataset/validate/1_1913.jpg
#   inflating: dataset/validate/1_1898.jpg
#   inflating: dataset/train/0_0970.txt
#   inflating: dataset/train/0_0984.jpg
#   inflating: dataset/train/0_0983.txt
#   inflating: dataset/train/0_0978.jpg
#   inflating: dataset/validate/1_1927.txt
#   inflating: dataset/train/0_0988.txt
#   inflating: dataset/train/0_0981.jpg
#   inflating: dataset/train/0_0987.txt
#   inflating: dataset/validate/1_1912.txt
#   inflating: dataset/train/0_0990.jpg
#   inflating: dataset/validate/1_1933.txt
#   inflating: dataset/train/0_1001.txt
#   inflating: dataset/train/0_0968.txt
#   inflating: dataset/validate/1_1890.txt
#   inflating: dataset/validate/1_1914.txt
#   inflating: dataset/train/0_0969.jpg
#   inflating: dataset/validate/1_1892.txt
#   inflating: dataset/validate/1_1893.jpg
#   inflating: dataset/train/0_0998.txt
#   inflating: dataset/validate/1_1891.txt
#   inflating: dataset/train/0_0980.jpg
#   inflating: dataset/train/0_0975.jpg
#   inflating: dataset/validate/1_1938.jpg
#   inflating: dataset/train/0_0989.txt
#   inflating: dataset/train/0_0991.jpg
#   inflating: dataset/validate/1_1895.txt
#   inflating: dataset/train/0_0971.jpg
#   inflating: dataset/validate/1_1917.txt
#   inflating: dataset/validate/1_1944.txt
#   inflating: dataset/train/0_1008.txt
#   inflating: dataset/validate/1_1928.txt
#   inflating: dataset/validate/1_1932.jpg
#   inflating: dataset/train/0_0986.txt
#   inflating: dataset/train/0_0987.jpg
#   inflating: dataset/validate/1_1924.txt
#   inflating: dataset/validate/1_1905.jpg
#   inflating: dataset/train/0_0978.txt
#   inflating: dataset/train/0_1027.jpg
#   inflating: dataset/train/0_0984.txt
#   inflating: dataset/validate/1_1888.jpg
#   inflating: dataset/train/0_0993.txt
#   inflating: dataset/train/0_1009.jpg
#   inflating: dataset/validate/1_1940.jpg
#   inflating: dataset/train/0_0985.jpg
#   inflating: dataset/validate/1_1910.txt
#   inflating: dataset/train/0_0988.jpg
#   inflating: dataset/validate/1_1912.jpg
#   inflating: dataset/validate/1_1886.jpg
#   inflating: dataset/train/0_0981.txt
#   inflating: dataset/train/0_0993.jpg
#   inflating: dataset/train/0_1002.txt
#   inflating: dataset/train/0_0989.jpg
#   inflating: dataset/validate/1_1935.jpg
#   inflating: dataset/train/0_0995.jpg
#   inflating: dataset/validate/1_1922.txt
#   inflating: dataset/validate/1_1909.txt
#   inflating: dataset/validate/1_1888.txt
#   inflating: dataset/validate/1_1896.jpg
#   inflating: dataset/validate/1_1898.txt
#   inflating: dataset/train/0_0996.jpg
#   inflating: dataset/train/0_1009.txt
#   inflating: dataset/validate/1_1906.txt
#   inflating: dataset/validate/1_1911.jpg
#   inflating: dataset/validate/1_1941.jpg
#   inflating: dataset/validate/1_1916.txt
#   inflating: dataset/validate/1_1911.txt
#   inflating: dataset/validate/1_1890.jpg
#   inflating: dataset/train/0_1006.txt
#   inflating: dataset/train/0_0992.txt
#   inflating: dataset/validate/1_1918.txt
#   inflating: dataset/validate/1_1894.jpg
#   inflating: dataset/validate/1_1919.jpg
#   inflating: dataset/validate/1_1900.jpg
#   inflating: dataset/validate/1_1907.txt
#   inflating: dataset/train/0_1010.txt
#   inflating: dataset/train/0_1007.jpg
#   inflating: dataset/validate/1_1921.jpg
#   inflating: dataset/train/0_0999.jpg
#   inflating: dataset/train/0_1013.txt
#   inflating: dataset/train/0_0992.jpg
#   inflating: dataset/train/0_1021.txt
#   inflating: dataset/train/0_1012.jpg
#   inflating: dataset/train/0_1017.jpg
#   inflating: dataset/train/0_0986.jpg
#   inflating: dataset/validate/1_1924.jpg
#   inflating: dataset/train/0_0998.jpg
#   inflating: dataset/train/0_0995.txt
#   inflating: dataset/train/0_0985.txt
#   inflating: dataset/train/0_1008.jpg
#   inflating: dataset/train/0_1005.txt
#   inflating: dataset/train/0_1020.txt
#   inflating: dataset/validate/1_1902.jpg
#   inflating: dataset/train/0_1006.jpg
#   inflating: dataset/train/0_0997.jpg
#   inflating: dataset/train/0_1001.jpg
#   inflating: dataset/train/0_1003.txt
#   inflating: dataset/train/0_1004.txt
#   inflating: dataset/train/0_0994.txt
#   inflating: dataset/train/0_0996.txt
#   inflating: dataset/train/0_1002.jpg
#   inflating: dataset/train/0_1003.jpg
#   inflating: dataset/train/0_1020.jpg
#   inflating: dataset/train/0_1010.jpg
#   inflating: dataset/train/0_1007.txt
#   inflating: dataset/train/0_1000.jpg
#   inflating: dataset/train/0_1012.txt
#   inflating: dataset/train/0_1029.jpg
#   inflating: dataset/validate/0_1877.jpg
#   inflating: dataset/train/0_0948.jpg
#   inflating: dataset/validate/0_1868.jpg
#   inflating: dataset/validate/1_1882.jpg
#   inflating: dataset/validate/1_1564.txt
# Archive:  checkpoints.zip
# file #1:  bad zipfile offset (local header sig):  0
# file #2:  bad zipfile offset (local header sig):  74
#   inflating: checkpoints/yolov3_ckpt_0.pth

# %%
# !wget -c https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2023-09-11 13:06:27--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  16.6MB/s    in 15s
#
# 2023-09-11 13:06:43 (15.8 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !mkdir weights
# !mv yolov3.weights weights

# %% [markdown]
# # 패키지 설치 및 드라이브 마운트

# %%
# !pip install pillow
# !pip install tqdm
# !pip install terminaltables
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables
# Successfully installed terminaltables-3.1.10

# %% [markdown]
# 패키지 설치 시 `RESTART RUNTIME` 버튼이 나온다면 한 번 RESTART 시켜주고 다시 실행한다.

# %%
# from google.colab import drive
# drive.mount('/content/gdrive/')

# %%
# import os
# os.chdir('/content/gdrive/My Drive/novatus/mask-detection-yolov3')
# os.listdir()

# %% [markdown]
# # Training

# %% [markdown]
# ## Package import

# %%
from __future__ import division

from models import Darknet
from utils.utils import load_classes, weights_init_normal
from utils.datasets import ListDataset
from utils.parse_config import parse_data_config
from validate import evaluate

from terminaltables import AsciiTable

import os
import time
import argparse
from tqdm import tqdm

import torch
from torch.utils.data import DataLoader
from torch.autograd import Variable

import warnings
import easydict
warnings.filterwarnings("ignore", category=UserWarning)

# from utils.logger import *

# %% [markdown]
# ## Training Option Setting
# Training Option을 정해준다. 필요한 몇 가지 옵션을 설명하면, epoch은 Training 데이터셋을 몇 번 반복해서 학습할 것인가를 말하며 batch_size는 한 번에 학습할 이미지의 갯수이다. pretrained_weights는 기학습된 모델의 weights 경로이며, checkpoint_interval은 몇 epoch 마다 학습한 모델을 저장할 것인지를 말하며, evaluation_interval은 몇 epoch 마다 모델을 validation set으로 평가할 것인지를 말한다.
#
# 이번 실습에서는 시간 상 30 epoch까지 학습하는 training을 진행하려고 한다.

# %%
opt = easydict.EasyDict({
    'epochs': 1,
    'batch_size': 16,
    'gradient_accumulations': 2,
    'model_def': "config/yolov3_mask.cfg",
    'data_config': "config/mask_dataset.data",
    'pretrained_weights': "weights/yolov3.weights",  # weights/yolov3.weights, checkpoints/yolov3_ckpt_35.pth
    "n_cpu": 8,
    'img_size': 416,
    'checkpoint_interval': 10,
    'evaluation_interval': 5,
    'compute_map': True,
    'multiscale_training': True
})
print(opt)
# logger = Logger("logs")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# gpu를 사용가능하면 device에 cuda를 저장한다.

os.makedirs("checkpoints", exist_ok=True)
# checkpoints 폴더를 생성
# Out:
# {'epochs': 1, 'batch_size': 16, 'gradient_accumulations': 2, 'model_def': 'config/yolov3_mask.cfg', 'data_config': 'config/mask_dataset.data', 'pretrained_weights': 'weights/yolov3.weights', 'n_cpu': 8, 'img_size': 416, 'checkpoint_interval': 10, 'evaluation_interval': 5, 'compute_map': True, 'multiscale_training': True}

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 데이터와 모델 로딩

# %%
# 데이터셋의 경로와 클래스의 이름 등을 가져온다.
data_config = parse_data_config(opt.data_config)

# %%
data_config
# Out:
# {'gpus': '0,1,2,3',
#  'num_workers': '10',
#  'classes': '2',
#  'train': 'data/mask_dataset_train.txt',
#  'valid': 'data/mask_dataset_validate.txt',
#  'names': 'data/mask_dataset.names',
#  'backup': 'backup/',
#  'eval': 'coco'}

# %%
# data_config["train"] = 'data/small_mask_dataset_train.txt'
# data_config["valid"] = 'data/small_mask_dataset_validate.txt'
# data_config

# %%
# 데이터셋의 경로와 클래스의 이름 등을 가져온다.
train_path = data_config["train"]
valid_path = data_config["valid"]
class_names = load_classes(data_config["names"])

# dataset의 경로를 통해 ListDataset(dataset을 상속받은 class) 인스턴스를 만들고 이를 쉽게 가져올 수 있는 dataloader를 만든다.
dataset = ListDataset(train_path, augment=True, multiscale=opt.multiscale_training)
dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=opt.batch_size,
    shuffle=True,
    num_workers=opt.n_cpu,
    pin_memory=True,
    collate_fn=dataset.collate_fn,
)

# model을 정해준다. model 폴더에서 Darknet class 내에 yolov3 모델이 저장되어 있다. 모델에 관한 자세한 사항은 Darknet을 참고하자.
model = Darknet(opt.model_def).to(device)
model.apply(weights_init_normal)

# pretrained_weights를 load한다.
if opt.pretrained_weights:
    if opt.pretrained_weights.endswith(".pth"):
        model.load_state_dict(torch.load(opt.pretrained_weights))
    else:
        model.load_darknet_weights(opt.pretrained_weights)

# %% [markdown]
# ## Training

# %%
optimizer = torch.optim.Adam(model.parameters()) # Adam optimizer를 사용하며 model의 parameter를 인자로 넣어준다.

# to get mAP
to_get_mAP = None

for epoch in range(opt.epochs): # 미리 설정한 epoch 만큼 반복
    model.train()
    start_time = time.time()

    pbar = tqdm(dataloader)
    for batch_i, (_, imgs, targets) in enumerate(pbar): # dataloader 에서 batch_size 만큼씩 학습.
        batches_done = len(dataloader) * epoch + batch_i

        imgs = Variable(imgs.to(device))
        targets = Variable(targets.to(device), requires_grad=False)

        loss, outputs = model(imgs, targets) # model에서 부터 loss 계산
        loss.backward() # loss에 대한 gradient 계산

        if batches_done % opt.gradient_accumulations:
            optimizer.step() # 학습 진행
            optimizer.zero_grad() # gradient를 0으로 만든다.


        log_str = "---- [Epoch %d/%d, Batch %d/%d] ----" % (epoch, opt.epochs, batch_i, len(dataloader))
        log_str += f"Total loss {loss.item():.4f} "
        log_str += f" {time.time()-start_time:.0f}"
        print(log_str)


        model.seen += imgs.size(0)

    if epoch % opt.evaluation_interval==0 or epoch==opt.epochs: # validation set에 대해 mAP 성능평가
        try:
            print("\n---- Evaluating Model ----")
            # Evaluate the model on the validation set
            precision, recall, AP, f1, ap_class = evaluate(
                model,
                path=valid_path,
                iou_thres=0.5,
                conf_thres=0.5,
                nms_thres=0.5,
                img_size=opt.img_size,
                batch_size=4,
            )
            evaluation_metrics = [
                ("val_precision", precision.mean()),
                ("val_recall", recall.mean()),
                ("val_mAP", AP.mean()),
                ("val_f1", f1.mean()),
            ]
            # logger.list_of_scalars_summary(evaluation_metrics, epoch)

            # Print class APs and mAP
            ap_table = [["Index", "Class name", "AP"]]
            for i, c in enumerate(ap_class):
                ap_table += [[c, class_names[c], "%.5f" % AP[i]]]
            print(AsciiTable(ap_table).table)
            print(f"---- mAP {AP.mean()}")
            to_get_mAP = AP.mean()
        except:
            to_get_mAP = 999999999999

    if epoch % opt.checkpoint_interval == 0: # checkpoint_interval 마다 model weight 저장.
        torch.save(model.state_dict(), "checkpoints/yolov3_ckpt_{0}.pth".format(epoch))
# Out:
#   1%|          | 1/170 [00:09<27:02,  9.60s/it]
# ---- [Epoch 0/1, Batch 0/170] ----Total loss 165.8235  10
#   1%|          | 2/170 [00:10<12:04,  4.31s/it]
# ---- [Epoch 0/1, Batch 1/170] ----Total loss 153.5900  10
#   2%|▏         | 3/170 [00:11<07:37,  2.74s/it]
# ---- [Epoch 0/1, Batch 2/170] ----Total loss 147.6077  11
#   2%|▏         | 4/170 [00:12<05:51,  2.12s/it]
# ---- [Epoch 0/1, Batch 3/170] ----Total loss 149.4311  12
#   3%|▎         | 5/170 [00:13<04:51,  1.77s/it]
# ---- [Epoch 0/1, Batch 4/170] ----Total loss 155.1551  13
#   4%|▎         | 6/170 [00:14<04:01,  1.47s/it]
# ---- [Epoch 0/1, Batch 5/170] ----Total loss 159.4286  14
#   4%|▍         | 7/170 [00:14<03:08,  1.15s/it]
# ---- [Epoch 0/1, Batch 6/170] ----Total loss 144.0355  15
#   5%|▍         | 8/170 [00:15<02:46,  1.03s/it]
# ---- [Epoch 0/1, Batch 7/170] ----Total loss 143.6839  16
#   5%|▌         | 9/170 [00:16<02:43,  1.01s/it]
# ---- [Epoch 0/1, Batch 8/170] ----Total loss 149.9934  17
#   6%|▌         | 10/170 [00:17<02:21,  1.13it/s]
# ---- [Epoch 0/1, Batch 9/170] ----Total loss 140.2765  17
#   6%|▋         | 11/170 [00:17<02:07,  1.25it/s]
# ---- [Epoch 0/1, Batch 10/170] ----Total loss 147.0998  18
#   7%|▋         | 12/170 [00:18<02:06,  1.24it/s]
# ---- [Epoch 0/1, Batch 11/170] ----Total loss 148.6238  19
#   8%|▊         | 13/170 [00:19<02:09,  1.21it/s]
# ---- [Epoch 0/1, Batch 12/170] ----Total loss 141.8024  19
#   8%|▊         | 14/170 [00:20<02:12,  1.18it/s]
# ---- [Epoch 0/1, Batch 13/170] ----Total loss 141.6484  20
#   9%|▉         | 15/170 [00:20<01:51,  1.39it/s]
# ---- [Epoch 0/1, Batch 14/170] ----Total loss 140.4368  21
#   9%|▉         | 16/170 [00:21<01:49,  1.40it/s]
# ---- [Epoch 0/1, Batch 15/170] ----Total loss 138.8336  21
#  10%|█         | 17/170 [00:22<01:58,  1.29it/s]
# ---- [Epoch 0/1, Batch 16/170] ----Total loss 138.7001  22
#  11%|█         | 18/170 [00:22<01:42,  1.49it/s]
# ---- [Epoch 0/1, Batch 152/170] ----Total loss 22.3616  121
#  91%|█████████ | 154/170 [02:01<00:12,  1.31it/s]
# ---- [Epoch 0/1, Batch 153/170] ----Total loss 22.0515  122
#  91%|█████████ | 155/170 [02:02<00:10,  1.41it/s]
# ---- [Epoch 0/1, Batch 154/170] ----Total loss 22.7824  122
#  92%|█████████▏| 156/170 [02:03<00:11,  1.26it/s]
# ---- [Epoch 0/1, Batch 155/170] ----Total loss 23.2517  123
#  92%|█████████▏| 157/170 [02:04<00:09,  1.36it/s]
# ---- [Epoch 0/1, Batch 156/170] ----Total loss 21.2200  124
#  93%|█████████▎| 158/170 [02:04<00:09,  1.32it/s]
# ---- [Epoch 0/1, Batch 157/170] ----Total loss 21.0158  125
#  94%|█████████▎| 159/170 [02:05<00:08,  1.34it/s]
# ---- [Epoch 0/1, Batch 158/170] ----Total loss 22.1570  126
#  94%|█████████▍| 160/170 [02:06<00:07,  1.31it/s]
# ---- [Epoch 0/1, Batch 159/170] ----Total loss 21.0943  126
#  95%|█████████▍| 161/170 [02:07<00:07,  1.21it/s]
# ---- [Epoch 0/1, Batch 160/170] ----Total loss 21.8698  127
#  95%|█████████▌| 162/170 [02:08<00:06,  1.25it/s]
# ---- [Epoch 0/1, Batch 161/170] ----Total loss 23.4329  128
#  96%|█████████▌| 163/170 [02:08<00:05,  1.21it/s]
# ---- [Epoch 0/1, Batch 162/170] ----Total loss 22.0538  129
#  96%|█████████▋| 164/170 [02:09<00:04,  1.39it/s]
# ---- [Epoch 0/1, Batch 163/170] ----Total loss 22.3580  129
#  97%|█████████▋| 165/170 [02:09<00:03,  1.52it/s]
# ---- [Epoch 0/1, Batch 164/170] ----Total loss 28.0741  130
#  98%|█████████▊| 166/170 [02:10<00:02,  1.47it/s]
# ---- [Epoch 0/1, Batch 165/170] ----Total loss 19.9602  131
#  98%|█████████▊| 167/170 [02:11<00:02,  1.45it/s]
# ---- [Epoch 0/1, Batch 166/170] ----Total loss 19.4845  131
#  99%|█████████▉| 168/170 [02:11<00:01,  1.61it/s]
# ---- [Epoch 0/1, Batch 167/170] ----Total loss 20.1255  132
#  99%|█████████▉| 169/170 [02:12<00:00,  1.38it/s]
# ---- [Epoch 0/1, Batch 168/170] ----Total loss 23.6579  133
# 100%|██████████| 170/170 [02:13<00:00,  1.27it/s]
# ---- [Epoch 0/1, Batch 169/170] ----Total loss 20.5964  134
#
# ---- Evaluating Model ----
# Detecting objects: 100%|██████████| 291/291 [00:28<00:00, 10.27it/s]
# Computing AP: 100%|██████████| 2/2 [00:00<00:00, 108.50it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | MASK       | 0.11342 |
# | 1     | NO_MASK    | 0.30765 |
# +-------+------------+---------+
# ---- mAP 0.21053467764416217

# %% [markdown]
# # Memory 에러 방지를 위한 재시작
# ## 런타임 -> 런타임 다시 시작

# %% [markdown]
# # fine-tuning, 1 epoch 후 image_detect.py 실행

# %%
# !python image_detect.py --weights_path checkpoints/yolov3_ckpt_0.pth
# Out:
# Namespace(input_file_path='testing/input/images', output_path='testing/output/images', model_def='config/yolov3_mask.cfg', weights_path='checkpoints/yolov3_ckpt_0.pth', class_path='data/mask_dataset.names', conf_thres=0.8, nms_thres=0.3, frame_size=416)
#
# Performing object detection:
#
# img.jpg_______
# Done....
#
# 2QJR.jpg_______
# Done....
#
# images21.jpg_______
# Done....
#
# images.jpg_______
# Done....
#
# 1582552493.jpg_______
# Done....
#
# image2.jpg_______
# Done....

# %%
import os
import cv2
from google.colab.patches import cv2_imshow

# %%
output_path = './testing/output/images'
for img in os.listdir(output_path):
    img_raw = cv2.imread(os.path.join(output_path, img))
    img_raw = cv2.resize(img_raw, (480, 270))
    cv2_imshow(img_raw)
# Out:
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>

# %% [markdown]
# # fine-tuning, 35 epoch 후 image_detect.py 실행

# %%
# !python image_detect.py --weights_path checkpoints/yolov3_ckpt_35.pth
# Out:
# Namespace(input_file_path='testing/input/images', output_path='testing/output/images', model_def='config/yolov3_mask.cfg', weights_path='checkpoints/yolov3_ckpt_35.pth', class_path='data/mask_dataset.names', conf_thres=0.8, nms_thres=0.3, frame_size=416)
#
# Performing object detection:
#
# img.jpg_______
# 5 Detection found
# Done....
#
# 2QJR.jpg_______
# 11 Detection found
# Done....
#
# images21.jpg_______
# 8 Detection found
# Done....
#
# images.jpg_______
# 10 Detection found
# Done....
#
# 1582552493.jpg_______
# 9 Detection found
# Done....
#
# image2.jpg_______
# 6 Detection found
# Done....

# %%
output_path = './testing/output/images'
for img in os.listdir(output_path):
    img_raw = cv2.imread(os.path.join(output_path, img))
    img_raw = cv2.resize(img_raw, (480, 270))
    cv2_imshow(img_raw)
# Out:
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>
# <PIL.Image.Image image mode=RGB size=480x270>

# %% [markdown]
# # WebCam으로 동영상 녹화 후 detecting 하기

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def record_video(filename='./testing/input/videos/video.mp4'):

  # This function uses the take_photo() function provided by the Colab team as a
  # starting point, along with a bunch of stuff from Stack overflow, and some sample code
  # from: https://developer.mozilla.org/enUS/docs/Web/API/MediaStream_Recording_API

  js = Javascript("""
    async function recordVideo() {
      const options = { mimeType: "video/webm; codecs=vp9" };
      const div = document.createElement('div');
      const capture = document.createElement('button');
      const stopCapture = document.createElement("button");
      capture.textContent = "Start Recording";
      capture.style.background = "green";
      capture.style.color = "white";

      stopCapture.textContent = "Stop Recording";
      stopCapture.style.background = "red";
      stopCapture.style.color = "white";
      div.appendChild(capture);

      const video = document.createElement('video');
      const recordingVid = document.createElement("video");
      video.style.display = 'block';

      const stream = await navigator.mediaDevices.getUserMedia({video: true});
      let recorder = new MediaRecorder(stream, options);
      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => {
        capture.onclick = resolve;
      });
      recorder.start();
      capture.replaceWith(stopCapture);
      await new Promise((resolve) => stopCapture.onclick = resolve);
      recorder.stop();

      let recData = await new Promise((resolve) => recorder.ondataavailable = resolve);
      let arrBuff = await recData.data.arrayBuffer();
      stream.getVideoTracks()[0].stop();
      div.remove();

      let binaryString = "";
      let bytes = new Uint8Array(arrBuff);
      bytes.forEach((byte) => {
        binaryString += String.fromCharCode(byte);
      })
      return btoa(binaryString);
    }
    """)
  try:
    display(js)
    data = eval_js('recordVideo({})')
    binary = b64decode(data)
    with open(filename, "wb") as video_file:
      video_file.write(binary)
    print(
        f"Finished recording video. Saved binary under filename in current working directory: {filename}"
    )
  except Exception as err:
      # In case any exceptions arise
      print(str(err))
  return filename

# %%
# Run the function, get the video path as saved in your notebook, and play it back here.
from IPython.display import HTML
from base64 import b64encode

video_width = 300

video_path = record_video()
video_file = open(video_path, "r+b").read()

video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
HTML(f"""""")
# Out:
# Finished recording video. Saved binary under filename in current working directory: ./testing/input/videos/video.mp4

# %% [markdown]
# # MASK Detecting

# %%
from __future__ import division

from models import Darknet
from utils.utils import load_classes, non_max_suppression_output
from google.colab.patches import cv2_imshow
import argparse

import time
import cv2
import os
import torch
import numpy as np
from torch.autograd import Variable
import easydict

if __name__ == "__main__":

    opt = easydict.EasyDict({
    'input_file_path': "./testing/input/videos/video.mp4",
    'model_def': "config/yolov3_mask.cfg",
    'weights_path': "checkpoints/yolov3_ckpt_35.pth",
    'class_path': "data/mask_dataset.names",
    'conf_thres': 0.9,
    'nms_thres': 0.4,
    'frame_size': 416,
    'save_video': True,
    'output_path': "./testing/output/videos"
    })
    print(opt)

    # Output directory
    os.makedirs(opt.output_path, exist_ok=True)

    # checking for GPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Set up model
    model = Darknet(opt.model_def, img_size=opt.frame_size).to(device)

    # loading weights
    if opt.weights_path.endswith(".weights"):
        model.load_darknet_weights(opt.weights_path)  # Load weights
    else:
        model.load_state_dict(torch.load(opt.weights_path))  # Load checkpoints

    # Set in evaluation mode
    model.eval()

    # Extracts class labels from file
    classes = load_classes(opt.class_path)

    # ckecking for GPU for Tensor
    Tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor

    # camara capture
    cap = cv2.VideoCapture(opt.input_file_path)
    assert cap.isOpened(), 'Cannot capture source'

    # Video feed dimensions
    _, frame = cap.read()
    v_height, v_width = frame.shape[:2]

    # print(v_height,v_width)

    # Output saving
    if(opt.save_video):
        fourcc = cv2.VideoWriter_fourcc(*'MP4V')

        filename = opt.input_file_path.split("/")[-1]
        filepath = os.path.join(opt.output_path,filename)

        #fps = cap.get(cv2.CAP_PROP_FPS)
        out = cv2.VideoWriter(filepath, fourcc, 25, (v_width, v_height))

    print("\nPerforming object detection:")

    # For a black image
    x = y = v_height if v_height > v_width else v_width

    # Putting original image into black image
    start_new_i_height = int((y - v_height) / 2)
    start_new_i_width = int((x - v_width) / 2)

    # For accommodate results in original frame
    mul_constant = x / opt.frame_size
    # print(mul_constant)

    # for text in output
    t_size = cv2.getTextSize(" ", cv2.FONT_HERSHEY_PLAIN, 1, 1)[0]

    frames = fps = 0
    start = time.time()

    while _:

        # frame extraction => resizing => [BGR -> RGB] => [[0...255] -> [0...1]] => [[3, 416, 416] -> [416, 416, 3]]
        #                       => [[416, 416, 3] => [416, 416, 3, 1]] => [np_array -> tensor] => [tensor -> variable]

        # frame extraction
        _, org_frame = cap.read()
        # resizing to [416 x 416]
        if not _:
          break

        # Black image
        frame = np.zeros((x, y, 3), np.uint8)

        frame[start_new_i_height: (start_new_i_height + v_height),start_new_i_width: (start_new_i_width + v_width)] = org_frame

        # resizing to [416x 416]
        frame = cv2.resize(frame, (opt.frame_size, opt.frame_size))
        # [BGR -> RGB]
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # [[0...255] -> [0...1]]
        frame = np.asarray(frame) / 255
        # [[3, 416, 416] -> [416, 416, 3]]
        frame = np.transpose(frame, [2, 0, 1])
        # [[416, 416, 3] => [416, 416, 3, 1]]
        frame = np.expand_dims(frame, axis=0)
        # [np_array -> tensor]
        frame = torch.Tensor(frame)

        # plt.imshow(frame[0].permute(1,2,0))
        # plt.show()

        # [tensor -> variable]
        frame = Variable(frame.type(Tensor))

        # Get detections
        with torch.no_grad():
            detections = model(frame)
        detections = non_max_suppression_output(detections, opt.conf_thres, opt.nms_thres)

        # For each detection in detections
        detection = detections[0]
        if detection is not None:

            for x1, y1, x2, y2, conf, cls_conf, cls_pred in detection:

                # Accommodate bounding box in original frame
                x1 = int(x1 * mul_constant - start_new_i_width)
                y1 = int(y1 * mul_constant - start_new_i_height)
                x2 = int(x2 * mul_constant - start_new_i_width)
                y2 = int(y2 * mul_constant - start_new_i_height)

                # Bounding box making and setting Bounding box title
                if (int(cls_pred) == 0):
                    # WITH_MASK
                    cv2.rectangle(org_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                else:
                    # WITHOUT_MASK
                    cv2.rectangle(org_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)

                cv2.putText(org_frame, classes[int(cls_pred)] + ": %.2f" % conf, (x1, y1 + t_size[1] + 4),
                            cv2.FONT_HERSHEY_PLAIN, 1,
                            [225, 255, 255], 2)


        # FPS PRINTING
        # cv2.rectangle(org_frame, (0, 0), (175, 20), (0, 0, 0), -1)
        # cv2.putText(org_frame,"FPS : %3.2f" % (fps), (0, t_size[1] + 4),
        #             cv2.FONT_HERSHEY_PLAIN, 1,
        #             [255, 255, 255], 1)

        frames += 1
        fps = frames / (time.time() - start)

        # cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
        # cv2.setWindowProperty('frame', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

        if (opt.save_video):
            out.write(org_frame)

        #cv2_imshow(org_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    if (opt.save_video):
        out.release()

    cap.release()
    cv2.destroyAllWindows()
# Out:
# {'input_file_path': './testing/input/videos/video.mp4', 'model_def': 'config/yolov3_mask.cfg', 'weights_path': 'checkpoints/yolov3_ckpt_35.pth', 'class_path': 'data/mask_dataset.names', 'conf_thres': 0.9, 'nms_thres': 0.4, 'frame_size': 416, 'save_video': True, 'output_path': './testing/output/videos'}
#
# Performing object detection:
